# %%
import pandas as pd
import plotly.express as px

car_data = pd.read_csv("../vehicles_us.csv")  
car_data.head()

# %%
car_data.info()
car_data.isna().sum().sort_values(ascending=False).head(15)

# %%
fig = px.histogram(car_data, x="odometer", title="Distribución del odómetro")
fig.show()

# %%
fig = px.scatter(car_data, x="odometer", y="price", title="Precio vs Odómetro")
fig.show()

# %%
if "condition" in car_data.columns:
    px.box(car_data, x="condition", y="price", title="Precio por condición").show()
